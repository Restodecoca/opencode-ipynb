# %% [markdown]
# # Simple Notebook
#
# A tiny notebook for tests.

# %%
x = 1
y = 2
x + y

# %% [markdown]
# ## Section
#
# Some notes.

# %%
def greet(name):
    return f"hello, {name}"

greet("world")
